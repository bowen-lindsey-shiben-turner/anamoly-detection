# %% [markdown]
# ## Eplore Notebook For Question 6:
# - 6. What topics are grads continuing to reference after graduation and into their jobs (for each program)?

# %% [markdown]
# ### 1. First I need to take a look at my prepared DF

# %%
import acquire
import prepare
import warnings
warnings.filterwarnings('ignore')

# %%
df = prepare.prepare_logs()
df.head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id            ip     name  start_date    end_date  \
# 0        8.0  97.105.19.61  hampton  2015-09-22  2016-02-06
# 1        8.0  97.105.19.61  hampton  2015-09-22  2016-02-06
# 2        8.0  97.105.19.61  hampton  2015-09-22  2016-02-06
# 3        8.0  97.105.19.61  hampton  2015-09-22  2016-02-06
# 4       22.0  97.105.19.61    teddy  2018-01-08  2018-05-17
#
#             created_at           updated_at       program_id  \
# 0  2016-06-14 19:52:26  2016-06-14 19:52:26   full_stack_php
# 1  2016-06-14 19:52:26  2016-06-14 19:52:26   full_stack_php
# 2  2016-06-14 19:52:26  2016-06-14 19:52:26   full_stack_php
# 3  2016-06-14 19:52:26  2016-06-14 19:52:26   full_stack_php
# 4  2018-01-08 13:59:10  2018-01-08 13:59:10  full_stack_java
#
#              date_time
# 0  2018-01-26 09:55:03
# 1  2018-01-26 09:56:02
# 2  2018-01-26 09:56:05
# 3  2018-01-26 09:56:06
# 4  2018-01-26 09:56:24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900223 entries, 0 to 900222
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        900223 non-null  object
#  1   time        900223 non-null  object
#  2   path        900222 non-null  object
#  3   user_id     900223 non-null  int64
#  4   cohort_id   847330 non-null  float64
#  5   ip          900223 non-null  object
#  6   name        847330 non-null  object
#  7   start_date  847330 non-null  object
#  8   end_date    847330 non-null  object
#  9   created_at  847330 non-null  object
#  10  updated_at  847330 non-null  object
#  11  program_id  847330 non-null  object
#  12  date_time   900223 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 89.3+ MB

# %%
import pandas as pd
import acquire
import prepare
import os

def get_q6_eda_df():
    df = prepare.prepare_logs()
    df.date_time = pd.to_datetime(df.date_time)
      # convert dates to DTG
    dates = ['start_date', 'end_date', 'created_at', 'updated_at']
    for col in dates:
        df[col] = pd.to_datetime(df[col])
        # drop unnecessary columns
    df = df.drop(columns=(['date', 'time']))
    return df

# %%
df = get_q6_eda_df()
df.head()
# Out:
#                                   path  user_id  cohort_id            ip  \
# 0                                    /        1        8.0  97.105.19.61
# 1                              java-ii        1        8.0  97.105.19.61
# 2  java-ii/object-oriented-programming        1        8.0  97.105.19.61
# 3   slides/object_oriented_programming        1        8.0  97.105.19.61
# 4            javascript-i/conditionals        2       22.0  97.105.19.61
#
#       name start_date   end_date          created_at          updated_at  \
# 0  hampton 2015-09-22 2016-02-06 2016-06-14 19:52:26 2016-06-14 19:52:26
# 1  hampton 2015-09-22 2016-02-06 2016-06-14 19:52:26 2016-06-14 19:52:26
# 2  hampton 2015-09-22 2016-02-06 2016-06-14 19:52:26 2016-06-14 19:52:26
# 3  hampton 2015-09-22 2016-02-06 2016-06-14 19:52:26 2016-06-14 19:52:26
# 4    teddy 2018-01-08 2018-05-17 2018-01-08 13:59:10 2018-01-08 13:59:10
#
#         program_id           date_time
# 0   full_stack_php 2018-01-26 09:55:03
# 1   full_stack_php 2018-01-26 09:56:02
# 2   full_stack_php 2018-01-26 09:56:05
# 3   full_stack_php 2018-01-26 09:56:06
# 4  full_stack_java 2018-01-26 09:56:24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900223 entries, 0 to 900222
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   path        900222 non-null  object
#  1   user_id     900223 non-null  int64
#  2   cohort_id   847330 non-null  float64
#  3   ip          900223 non-null  object
#  4   name        847330 non-null  object
#  5   start_date  847330 non-null  datetime64[ns]
#  6   end_date    847330 non-null  datetime64[ns]
#  7   created_at  847330 non-null  datetime64[ns]
#  8   updated_at  847330 non-null  datetime64[ns]
#  9   program_id  847330 non-null  object
#  10  date_time   900223 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), float64(1), int64(1), object(4)
# memory usage: 75.5+ MB

# %%
df[df.program_id == 'data_science'].head(20)
# Out:
#                                            path  user_id  cohort_id  \
# 326053                                        /      466       34.0
# 326054                                        /      467       34.0
# 326055                                        /      468       34.0
# 326056                                        /      469       34.0
# 326057                                        /      470       34.0
# 326058                                        /      471       34.0
# 326059                                        /      472       34.0
# 326060                                        /      473       34.0
# 326061                                        /      474       34.0
# 326062                                        /      475       34.0
# 326063                                        /      476       34.0
# 326064                   3-sql/1-mysql-overview      470       34.0
# 326065                                        /      477       34.0
# 326066                                        /      472       34.0
# 326067                2-storytelling/bad-charts      467       34.0
# 326068  2-storytelling/misleading1_baseball.jpg      467       34.0
# 326069       2-storytelling/misleading1_fox.jpg      467       34.0
# 326070    2-storytelling/misleading3_deaths.jpg      467       34.0
# 326071                                        /      478       34.0
# 326072                                        /      479       34.0
#
#                   ip   name start_date   end_date          created_at  \
# 326053  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326054  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326055  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326056  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326057  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326058  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326059  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326060  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326061  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326062  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326063  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326064  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326065  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326066  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326067  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326068  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326069  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326070  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326071  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 326072  97.105.19.58  bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
#
#                 updated_at    program_id           date_time
# 326053 2019-08-20 14:38:55  data_science 2019-08-20 09:39:58
# 326054 2019-08-20 14:38:55  data_science 2019-08-20 09:39:59
# 326055 2019-08-20 14:38:55  data_science 2019-08-20 09:39:59
# 326056 2019-08-20 14:38:55  data_science 2019-08-20 09:40:02
# 326057 2019-08-20 14:38:55  data_science 2019-08-20 09:40:08
# 326058 2019-08-20 14:38:55  data_science 2019-08-20 09:40:15
# 326059 2019-08-20 14:38:55  data_science 2019-08-20 09:40:15
# 326060 2019-08-20 14:38:55  data_science 2019-08-20 09:40:17
# 326061 2019-08-20 14:38:55  data_science 2019-08-20 09:40:18
# 326062 2019-08-20 14:38:55  data_science 2019-08-20 09:40:19
# 326063 2019-08-20 14:38:55  data_science 2019-08-20 09:40:23
# 326064 2019-08-20 14:38:55  data_science 2019-08-20 09:40:28
# 326065 2019-08-20 14:38:55  data_science 2019-08-20 09:40:30
# 326066 2019-08-20 14:38:55  data_science 2019-08-20 09:40:30
# 326067 2019-08-20 14:38:55  data_science 2019-08-20 09:40:30
# 326068 2019-08-20 14:38:55  data_science 2019-08-20 09:40:30
# 326069 2019-08-20 14:38:55  data_science 2019-08-20 09:40:30
# 326070 2019-08-20 14:38:55  data_science 2019-08-20 09:40:30
# 326071 2019-08-20 14:38:55  data_science 2019-08-20 09:40:37
# 326072 2019-08-20 14:38:55  data_science 2019-08-20 09:40:40

# %% [markdown]
# ## To answer the question:
# - 6. What topics are grads continuing to reference after graduation and into their jobs (for each program)?
# - identify grads. These will be user_id's where date_time is > end date
# - identify programs accessed. create synthetic columns from path: topic (e.g. regression), resource (e.g. project)
# - goals:
#         - produce a visual that shows the most accessed resources, and
#         - average frequency of resource usage post grad, ie does it taper off after 1 month? 6 months?
#         - produce a visual that shows access to materials after graduation by program_id: which programs use reference material the most?

# %%
# get the list of page requests made by grads
access_after_grad_df = df[df.date_time > df.end_date]
access_after_grad_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200132 entries, 0 to 900222
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   path        200132 non-null  object
#  1   user_id     200132 non-null  int64
#  2   cohort_id   200132 non-null  float64
#  3   ip          200132 non-null  object
#  4   name        200132 non-null  object
#  5   start_date  200132 non-null  datetime64[ns]
#  6   end_date    200132 non-null  datetime64[ns]
#  7   created_at  200132 non-null  datetime64[ns]
#  8   updated_at  200132 non-null  datetime64[ns]
#  9   program_id  200132 non-null  object
#  10  date_time   200132 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), float64(1), int64(1), object(4)
# memory usage: 18.3+ MB

# %%
access_after_grad_df[access_after_grad_df.program_id=='data_science'].path.value_counts().head(13)
# Out:
# /                                                 1446
# search/search_index.json                           493
# sql/mysql-overview                                 275
# classification/overview                            267
# classification/scale_features_or_not.svg           220
# anomaly-detection/AnomalyDetectionCartoon.jpeg     193
# anomaly-detection/overview                         191
# fundamentals/AI-ML-DL-timeline.jpg                 189
# fundamentals/modern-data-scientist.jpg             187
# fundamentals/intro-to-data-science                 184
# 1-fundamentals/modern-data-scientist.jpg           128
# 1-fundamentals/1.1-intro-to-data-science           127
# 1-fundamentals/AI-ML-DL-timeline.jpg               127
# Name: path, dtype: int64

# %% [markdown]
# - 1. look in df.path
# - 2. if df.path == '/' then home
# - 3.

# %%
# create new DF columns for coursework_topic and specific_resource
access_after_grad_df['coursework_topic'] = ''
access_after_grad_df['specific_resource'] = ''
access_after_grad_df['further_info'] = ''
access_after_grad_df.head(10)
# Out:
#                                    path  user_id  cohort_id             ip  \
# 0                                     /        1        8.0   97.105.19.61
# 1                               java-ii        1        8.0   97.105.19.61
# 2   java-ii/object-oriented-programming        1        8.0   97.105.19.61
# 3    slides/object_oriented_programming        1        8.0   97.105.19.61
# 30                                    /       11        1.0   97.105.19.61
# 31                         javascript-i       11        1.0   97.105.19.61
# 33               javascript-i/functions       11        1.0   97.105.19.61
# 58               javascript-i/functions        1        8.0   97.105.19.61
# 72                           index.html       21       16.0  71.137.146.71
# 73                               java-i       21       16.0  71.137.146.71
#
#        name start_date   end_date          created_at          updated_at  \
# 0   hampton 2015-09-22 2016-02-06 2016-06-14 19:52:26 2016-06-14 19:52:26
# 1   hampton 2015-09-22 2016-02-06 2016-06-14 19:52:26 2016-06-14 19:52:26
# 2   hampton 2015-09-22 2016-02-06 2016-06-14 19:52:26 2016-06-14 19:52:26
# 3   hampton 2015-09-22 2016-02-06 2016-06-14 19:52:26 2016-06-14 19:52:26
# 30   arches 2014-02-04 2014-04-22 2016-06-14 19:52:26 2016-06-14 19:52:26
# 31   arches 2014-02-04 2014-04-22 2016-06-14 19:52:26 2016-06-14 19:52:26
# 33   arches 2014-02-04 2014-04-22 2016-06-14 19:52:26 2016-06-14 19:52:26
# 58  hampton 2015-09-22 2016-02-06 2016-06-14 19:52:26 2016-06-14 19:52:26
# 72  niagara 2016-10-26 2017-03-09 2016-10-26 02:34:05 2016-10-26 14:30:19
# 73  niagara 2016-10-26 2017-03-09 2016-10-26 02:34:05 2016-10-26 14:30:19
#
#          program_id           date_time coursework_topic specific_resource  \
# 0    full_stack_php 2018-01-26 09:55:03
# 1    full_stack_php 2018-01-26 09:56:02
# 2    full_stack_php 2018-01-26 09:56:05
# 3    full_stack_php 2018-01-26 09:56:06
# 30   full_stack_php 2018-01-26 10:14:47
# 31   full_stack_php 2018-01-26 10:14:51
# 33   full_stack_php 2018-01-26 10:15:02
# 58   full_stack_php 2018-01-26 10:40:15
# 72  full_stack_java 2018-01-26 10:59:02
# 73  full_stack_java 2018-01-26 10:59:06
#
#    further_info
# 0
# 1
# 2
# 3
# 30
# 31
# 33
# 58
# 72
# 73

# %%
def get_coursework_topic_and_specific_resource(df):
    paths = df.path.values
    # returns array of paths
    coursework_topic = []
    specific_resource = []
    further_info = []
    for path in paths:
        if path == '/':
            coursework_topic.append('Homepage')
            specific_resource.append('None')
            further_info.append('None')
        elif len(path.split('/')) > 2:
            coursework_topic.append(path.split('/')[0])
            specific_resource.append(path.split('/')[1])
            further_info.append(path.split('/')[2])
        elif len(path.split('/')) > 1:
            coursework_topic.append(path.split('/')[0])
            specific_resource.append(path.split('/')[1])
            further_info.append('None')
        else:
             coursework_topic.append(path.split('/')[0])
             specific_resource.append('None')
             further_info.append('None')
    df.coursework_topic = coursework_topic
    df.specific_resource = specific_resource
    df.further_info = further_info
    return df

# %%
access_df = get_coursework_topic_and_specific_resource(access_after_grad_df)
access_df.sample(20)
# Out:
#                                                      path  user_id  cohort_id  \
# 496009                            6-regression/1-overview      248       28.0
# 27828                                              jquery        1        8.0
# 157584                                                  /      190       24.0
# 721437                javascript-i/introduction/operators      546       28.0
# 138619  appendix/further-reading/java/intellij-tomcat-...       64        1.0
# 439160                  java-i/syntax-types-and-variables      211       28.0
# 648320         html-css/css-i/flexbox/flexbox-in-practice      570       53.0
# 652315                              mysql/sample-database      509       51.0
# 524813  10-anomaly-detection/2-continuous-probabilisti...       11       28.0
# 296401                                       javascript-i      428       28.0
# 808740                    storytelling/connecting-to-data      248       28.0
# 886232                                   jquery/selectors      630       28.0
# 647248                                       javascript-i       64       28.0
# 699508                      java-ii/dependency-management       64       28.0
# 423300                                   jquery/selectors      315       26.0
# 459328                          appendix/cli-git-overview       11       28.0
# 823458           classification/scale_features_or_not.svg      485       34.0
# 649108                                      javascript-ii      613       56.0
# 661246                    spring/fundamentals/controllers      555       53.0
# 682753                              mysql/sample-database      641       57.0
#
#                      ip       name start_date   end_date          created_at  \
# 496009  173.173.115.201      staff 2014-02-04 2014-02-04 2018-12-06 17:04:19
# 27828      97.105.19.61    hampton 2015-09-22 2016-02-06 2016-06-14 19:52:26
# 157584    72.181.104.64  voyageurs 2018-05-29 2018-10-11 2018-05-25 22:25:57
# 721437     67.11.146.88      staff 2014-02-04 2014-02-04 2018-12-06 17:04:19
# 138619     97.105.19.58     arches 2014-02-04 2014-04-22 2016-06-14 19:52:26
# 439160     97.105.19.58      staff 2014-02-04 2014-02-04 2018-12-06 17:04:19
# 648320     67.10.164.55    fortuna 2020-01-13 2020-06-23 2020-01-13 21:17:08
# 652315    108.71.183.46     deimos 2019-09-16 2020-02-27 2019-09-16 13:07:04
# 524813   76.185.145.231      staff 2014-02-04 2014-02-04 2018-12-06 17:04:19
# 296401     97.105.19.58      staff 2014-02-04 2014-02-04 2018-12-06 17:04:19
# 808740  173.173.115.201      staff 2014-02-04 2014-02-04 2018-12-06 17:04:19
# 886232  162.233.171.112      staff 2014-02-04 2014-02-04 2018-12-06 17:04:19
# 647248    71.150.217.33      staff 2014-02-04 2014-02-04 2018-12-06 17:04:19
# 699508    71.150.217.33      staff 2014-02-04 2014-02-04 2018-12-06 17:04:19
# 423300     97.105.19.58     xanadu 2018-09-17 2019-02-08 2018-09-17 19:09:51
# 459328     97.105.19.58      staff 2014-02-04 2014-02-04 2018-12-06 17:04:19
# 823458   173.174.142.84      bayes 2019-08-19 2020-01-30 2019-08-20 14:38:55
# 649108    104.10.49.137       apex 2020-02-24 2020-07-29 2020-02-24 15:39:33
# 661246    136.50.32.151    fortuna 2020-01-13 2020-06-23 2020-01-13 21:17:08
# 682753    67.11.211.115   ganymede 2020-03-23 2020-08-20 2020-03-23 17:52:16
#
#                 updated_at       program_id           date_time  \
# 496009 2018-12-06 17:04:19  full_stack_java 2020-03-30 10:44:50
# 27828  2016-06-14 19:52:26   full_stack_php 2018-03-19 11:12:09
# 157584 2018-05-25 22:25:57  full_stack_java 2018-11-17 17:55:11
# 721437 2018-12-06 17:04:19  full_stack_java 2020-11-04 11:58:56
# 138619 2016-06-14 19:52:26   full_stack_php 2018-10-10 09:24:06
# 439160 2018-12-06 17:04:19  full_stack_java 2020-01-27 08:21:54
# 648320 2020-01-13 21:17:08  full_stack_java 2020-08-23 19:40:39
# 652315 2019-09-16 13:07:04  full_stack_java 2020-08-26 13:03:15
# 524813 2018-12-06 17:04:19  full_stack_java 2020-04-27 14:39:44
# 296401 2018-12-06 17:04:19  full_stack_java 2019-07-11 13:46:24
# 808740 2018-12-06 17:04:19  full_stack_java 2021-02-02 16:36:34
# 886232 2018-12-06 17:04:19  full_stack_java 2021-04-12 14:06:36
# 647248 2018-12-06 17:04:19  full_stack_java 2020-08-21 15:49:15
# 699508 2018-12-06 17:04:19  full_stack_java 2020-10-14 12:12:54
# 423300 2018-09-17 19:09:51  full_stack_java 2020-01-06 11:48:11
# 459328 2018-12-06 17:04:19  full_stack_java 2020-02-18 10:56:40
# 823458 2019-08-20 14:38:55     data_science 2021-02-20 17:38:20
# 649108 2020-07-29 18:41:13  full_stack_java 2020-08-24 11:18:31
# 661246 2020-01-13 21:17:08  full_stack_java 2020-09-06 23:02:38
# 682753 2020-03-23 17:52:16  full_stack_java 2020-09-27 12:53:52
#
#             coursework_topic                   specific_resource further_info
# 496009          6-regression                          1-overview         None
# 27828                 jquery                                None         None
# 157584              Homepage                                None         None
# 721437          javascript-i                        introduction    operators
# 138619              appendix                     further-reading         java
# 439160                java-i          syntax-types-and-variables         None
# 648320              html-css                               css-i      flexbox
# 652315                 mysql                     sample-database         None
# 524813  10-anomaly-detection  2-continuous-probabilistic-methods         None
# 296401          javascript-i                                None         None
# 808740          storytelling                  connecting-to-data         None
# 886232                jquery                           selectors         None
# 647248          javascript-i                                None         None
# 699508               java-ii               dependency-management         None
# 423300                jquery                           selectors         None
# 459328              appendix                    cli-git-overview         None
# 823458        classification           scale_features_or_not.svg         None
# 649108         javascript-ii                                None         None
# 661246                spring                        fundamentals  controllers
# 682753                 mysql                     sample-database         None

# %%
# now I want to see which topics are being accessed the most, overall and then by population (DS, Web_dev, etc)
access_df.groupby('program_id').coursework_topic.value_counts().head(15).plot.barh()
# Out:
# <AxesSubplot:ylabel='program_id,coursework_topic'>

# %%
access_df.groupby('program_id').coursework_topic.value_counts().max()
# Out:
# 15442

# %%
access_df.groupby('program_id').coursework_topic.value_counts().idxmax(), access_df.groupby('program_id').coursework_topic.value_counts().max()
# Out:
# (('full_stack_java', 'javascript-i'), 15442)

# %%
access_df.groupby('program_id')['program_id'=='data_science'].coursework_topic.value_counts().head(15).plot.barh()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/3n/86q7c8d16r51w8vg4g5kwq280000gn/T/ipykernel_11280/683711968.py in <module>
# ----> 1 access_df.groupby('program_id')['program_id'=='data_science'].coursework_topic.value_counts().head(15).plot.barh()
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1536                 stacklevel=2,
#    1537             )
# -> 1538         return super().__getitem__(key)
#    1539
#    1540     def _gotitem(self, key, ndim: int, subset=None):
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/base.py in __getitem__(self, key)
#     230         else:
#     231             if key not in self.obj:
# --> 232                 raise KeyError(f"Column not found: {key}")
#     233             subset = self.obj[key]
#     234             ndim = subset.ndim
#
# KeyError: 'Column not found: False'
