# %%
import acquire

# %%
df = acquire.get_log_data()
df.head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id            ip    id     name     slack  start_date    end_date  \
# 0        8.0  97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 1        8.0  97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 2        8.0  97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 3        8.0  97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 4       22.0  97.105.19.61  22.0    Teddy    #teddy  2018-01-08  2018-05-17
#
#             created_at           updated_at deleted_at  program_id
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900223 entries, 0 to 900222
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        900223 non-null  object
#  1   time        900223 non-null  object
#  2   path        900222 non-null  object
#  3   user_id     900223 non-null  int64
#  4   cohort_id   847330 non-null  float64
#  5   ip          900223 non-null  object
#  6   id          847330 non-null  float64
#  7   name        847330 non-null  object
#  8   slack       847330 non-null  object
#  9   start_date  847330 non-null  object
#  10  end_date    847330 non-null  object
#  11  created_at  847330 non-null  object
#  12  updated_at  847330 non-null  object
#  13  deleted_at  0 non-null       object
#  14  program_id  847330 non-null  float64
# dtypes: float64(3), int64(1), object(11)
# memory usage: 103.0+ MB

# %%
null_props = df.isna().mean()
null_props
# Out:
# date          0.000000
# time          0.000000
# path          0.000001
# user_id       0.000000
# cohort_id     0.058755
# ip            0.000000
# id            0.058755
# name          0.058755
# slack         0.058755
# start_date    0.058755
# end_date      0.058755
# created_at    0.058755
# updated_at    0.058755
# deleted_at    1.000000
# program_id    0.058755
# dtype: float64

# %%
# initial notes: 

# columns to change to numeric: dates (pd.to_datetime)

# columns to drop: 900_223 nulls (100%); 

# drop one or the other: either 'name' or 'slack', id/cohort id, 

# concat date and time and set as index

# columns to create: before, during, after to categorize access date WRT cohort timeline

# %%
# let's map the program type (DS, Web Dev, Full Stack) to the appropriate number

# %%
df = df.drop(columns=(['slack', 'id', 'deleted_at']))
df.head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id            ip     name  start_date    end_date  \
# 0        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 1        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 2        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 3        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 4       22.0  97.105.19.61    Teddy  2018-01-08  2018-05-17
#
#             created_at           updated_at  program_id
# 0  2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# 1  2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# ...

# %%
df.program_id.value_counts()
# Out:
# 2.0    713365
# 3.0    103412
# 1.0     30548
# 4.0         5
# Name: program_id, dtype: int64

# %%
df[df.program_id==1].head()
# Program_ID_1: Hampton is 'full_stack_PHP'
# Out:
#           date      time                                 path  user_id  \
# 0   2018-01-26  09:55:03                                    /        1
# 1   2018-01-26  09:56:02                              java-ii        1
# 2   2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3   2018-01-26  09:56:06   slides/object_oriented_programming        1
# 30  2018-01-26  10:14:47                                    /       11
#
#     cohort_id            ip     name  start_date    end_date  \
# 0         8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 1         8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 2         8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 3         8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 30        1.0  97.105.19.61   Arches  2014-02-04  2014-04-22
#
#              created_at           updated_at  program_id
# 0   2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# ...

# %%
df[df.program_id==1].end_date.max()
# Out:
# '2017-09-22'

# %%
df[df.program_id==2].head()
# Program_ID_2: Teddy is 'full_stack_java'
# Out:
#          date      time                       path  user_id  cohort_id  \
# 4  2018-01-26  09:56:24  javascript-i/conditionals        2       22.0
# 5  2018-01-26  09:56:41         javascript-i/loops        2       22.0
# 6  2018-01-26  09:56:46  javascript-i/conditionals        3       22.0
# 7  2018-01-26  09:56:48     javascript-i/functions        3       22.0
# 8  2018-01-26  09:56:59         javascript-i/loops        2       22.0
#
#              ip   name  start_date    end_date           created_at  \
# 4  97.105.19.61  Teddy  2018-01-08  2018-05-17  2018-01-08 13:59:10
# 5  97.105.19.61  Teddy  2018-01-08  2018-05-17  2018-01-08 13:59:10
# 6  97.105.19.61  Teddy  2018-01-08  2018-05-17  2018-01-08 13:59:10
# 7  97.105.19.61  Teddy  2018-01-08  2018-05-17  2018-01-08 13:59:10
# 8  97.105.19.61  Teddy  2018-01-08  2018-05-17  2018-01-08 13:59:10
#
#             updated_at  program_id
# 4  2018-01-08 13:59:10         2.0
# 5  2018-01-08 13:59:10         2.0
# ...

# %%
df[df.program_id==2].end_date.max()
# Out:
# '2021-10-01'

# %%
df[df.program_id==3].head()
# Program_ID_3 is 'data_science'
# Out:
#               date      time path  user_id  cohort_id            ip   name  \
# 326053  2019-08-20  09:39:58    /      466       34.0  97.105.19.58  Bayes
# 326054  2019-08-20  09:39:59    /      467       34.0  97.105.19.58  Bayes
# 326055  2019-08-20  09:39:59    /      468       34.0  97.105.19.58  Bayes
# 326056  2019-08-20  09:40:02    /      469       34.0  97.105.19.58  Bayes
# 326057  2019-08-20  09:40:08    /      470       34.0  97.105.19.58  Bayes
#
#         start_date    end_date           created_at           updated_at  \
# 326053  2019-08-19  2020-01-30  2019-08-20 14:38:55  2019-08-20 14:38:55
# 326054  2019-08-19  2020-01-30  2019-08-20 14:38:55  2019-08-20 14:38:55
# 326055  2019-08-19  2020-01-30  2019-08-20 14:38:55  2019-08-20 14:38:55
# 326056  2019-08-19  2020-01-30  2019-08-20 14:38:55  2019-08-20 14:38:55
# 326057  2019-08-19  2020-01-30  2019-08-20 14:38:55  2019-08-20 14:38:55
#
#         program_id
# 326053         3.0
# 326054         3.0
# ...

# %%
df[df.program_id==3].end_date.max()
# Out:
# '2021-09-03'

# %%
df[df.program_id==4].head()
# Program_ID_4 is 'front_end_programming'
# Out:
#              date      time                                         path  \
# 31627  2018-03-22  19:01:49                                            /
# 31628  2018-03-22  19:01:54                             content/html-css
# 31629  2018-03-22  19:01:54  content/html-css/gitbook/images/favicon.ico
# 31630  2018-03-22  19:02:47                             content/html-css
# 31631  2018-03-22  19:02:52           content/html-css/introduction.html
#
#        user_id  cohort_id             ip    name  start_date    end_date  \
# 31627      152        9.0  207.68.209.17  Apollo  2015-03-30  2015-07-29
# 31628      152        9.0  207.68.209.17  Apollo  2015-03-30  2015-07-29
# 31629      152        9.0  207.68.209.17  Apollo  2015-03-30  2015-07-29
# 31630      152        9.0  207.68.209.17  Apollo  2015-03-30  2015-07-29
# 31631      152        9.0  207.68.209.17  Apollo  2015-03-30  2015-07-29
#
#                 created_at           updated_at  program_id
# ...

# %%
df[df.program_id==4].end_date.max()
# Out:
# '2015-07-29'

# %%
(df.created_at == df.updated_at).value_counts()
# Out:
# True     795294
# False    104929
# dtype: int64

# %%
df[df.created_at==df.updated_at].head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id            ip     name  start_date    end_date  \
# 0        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 1        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 2        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 3        8.0  97.105.19.61  Hampton  2015-09-22  2016-02-06
# 4       22.0  97.105.19.61    Teddy  2018-01-08  2018-05-17
#
#             created_at           updated_at  program_id
# 0  2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# 1  2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900223 entries, 0 to 900222
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        900223 non-null  object
#  1   time        900223 non-null  object
#  2   path        900222 non-null  object
#  3   user_id     900223 non-null  int64
#  4   cohort_id   847330 non-null  float64
#  5   ip          900223 non-null  object
#  6   name        847330 non-null  object
#  7   start_date  847330 non-null  object
#  8   end_date    847330 non-null  object
#  9   created_at  847330 non-null  object
#  10  updated_at  847330 non-null  object
#  11  program_id  847330 non-null  float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 82.4+ MB

# %%
df.program_id = df.program_id.map({1.0:'full_stack_php', 2.0:'full_stack_java', 3.0:'data_science', 4.0:'front_end_programming'})
df.sample(20)

# s.map({'cat': 'kitten', 'dog': 'puppy'})
# Out:
#               date      time  \
# 604928  2020-07-20  09:24:58
# 503372  2020-04-06  08:33:19
# 827206  2021-02-24  15:23:42
# 535408  2020-05-06  16:56:26
# 256160  2019-04-30  20:18:35
# 456827  2020-02-14  08:31:08
# 208189  2019-02-26  21:43:13
# 109105  2018-08-19  15:36:08
# 37715   2018-04-03  16:46:09
# 4397    2018-02-02  12:23:50
# 25604   2018-03-15  15:09:09
# 229836  2019-03-28  09:42:06
# 23291   2018-03-12  15:04:56
# 504274  2020-04-06  14:11:44
# 62111   2018-05-31  08:57:45
# 653744  2020-08-27  15:49:25
# 217160  2019-03-11  15:28:23
# 240381  2019-04-10  09:09:33
# 52138   2018-05-03  10:58:28
# 305050  2019-07-22  15:31:41
#
#                                                      path  user_id  cohort_id  \
# 604928                           search/search_index.json      642       57.0
# 503372                                       javascript-i      613       56.0
# 827206                  java-i/syntax-types-and-variables      723        NaN
# ...

# %%
df.date = pd.to_datetime(df.date)

# %%
# set datetime index
df.set_index('date', inplace=True)
# drop 
df = df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/3n/86q7c8d16r51w8vg4g5kwq280000gn/T/ipykernel_9380/2366472954.py in <module>
#       2 df.set_index('date', inplace=True)
#       3 # drop
# ----> 4 df = df.drop(columns=['Unnamed: 0'])
#       5 df.head()
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %% [markdown]
# ## Initial thoughts:
# - the traffic without a cohort attribution is most likely general web traffic, not from CodeUp students. If we are scanning for anomalies/outliers, this is where the malicious traffic will most likely be coming from.
# - programs 4 and 1 are the discontinued courses at codeup.
# - make synthetic columns from path: program, module, etc to categorize the pages under programs and program modules

# %%
dates = ['start_date', 'end_date', 'created_at', 'updated_at']
for col in dates:
    df[col] = pd.to_datetime(df[col])

# %%
df.head()

# %%
df.info()

# %%
import acquire
import pandas as pd
import os

def prepare_logs(use_cache=True):
    """This function takes in the DataFrame from the get_log_data function located in the acquire file.
    Args: none. 
    Columns dropped: 'slack', 'id', and 'deleted_at'.
    Columns renamed: mapped values for program type to integers in 'program_id' column.
    Columns converted: 'start_date', 'end_date', 'created_at', 'updated_at' converted to DTG format.
    Columns concat: 'date' and 'time', converted to DTG
    Returns: prepared DF, and CSV named 'codeup_logs.csv'
      """
      #use local cache from CSV if available
    filename = "codeup_logs.csv"
    if os.path.isfile(filename) and use_cache:
        return pd.read_csv(filename)
    # acquire the data
    df = df = acquire.get_log_data()
    # drop unnecessary columns
    df = df.drop(columns=(['slack', 'id', 'deleted_at', 'Unnamed: 0']))
    # map programs to program ids
    df.program_id = df.program_id.map({1.0:'full_stack_php', 
    2.0:'full_stack_java', 3.0:'data_science', 4.0:'front_end_programming'})
    # convert dates to DTG
    dates = ['start_date', 'end_date', 'created_at', 'updated_at']
    for col in dates:
        df[col] = pd.to_datetime(df[col])
    # change cohort names to lower case
    df.name = df.name.str.lower()
    # convert date-time to DTG
    df['date_time'] = df.date + " " + df.time
    df.date_time = pd.to_datetime(df.date_time)
    # drop unnecessary columns
    df = df.drop(columns=(['date', 'time']))
    # add 'to_csv'
    df.to_csv(filename, index=False)
    return df

# %%
df = prepare_logs()
df.head()
# Out:
#          date      time                                 path  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id            ip     name  start_date    end_date  \
# 0        8.0  97.105.19.61  hampton  2015-09-22  2016-02-06
# 1        8.0  97.105.19.61  hampton  2015-09-22  2016-02-06
# 2        8.0  97.105.19.61  hampton  2015-09-22  2016-02-06
# 3        8.0  97.105.19.61  hampton  2015-09-22  2016-02-06
# 4       22.0  97.105.19.61    teddy  2018-01-08  2018-05-17
#
#             created_at           updated_at       program_id  \
# 0  2016-06-14 19:52:26  2016-06-14 19:52:26   full_stack_php
# ...
